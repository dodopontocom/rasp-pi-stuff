# %%
from hashlib import sha256
import json
import time

# %%
chain = [
	{
		"remetente": "Rafael Dias",
       		"destinatario": "Teste",
       		"mensagem": "600 Reais"
	},
	{
		"remetente": "TESTE",
	       	"destinatario": "Fulano de Tal",
       		"mensagem": "700 Reais"
	}
]

block_chain = []

# %%
def get_time():
	return time.time()

def isValidHashDifficulty(hash, difficulty):
	count = 0
	for i in hash:
		count += 1
		if(i != '0'):
			break
	return count > difficulty

def generate_hash(block):
	nonce = 0
	block["nonce"] = nonce
	hash = sha256(json.dumps(block).encode()).hexdigest()
	while(not isValidHashDifficulty(hash, 4)):
		nonce = nonce + 1
		block["nonce"] = nonce
		hash = sha256(json.dumps(block).encode()).hexdigest()
		#hash = sha256(json.dumps(block)).hexdigest()
	return hash


def add_block(block):
	if(len(block_chain) == 0):
		block["timestamp"] = get_time()
		block["hash"] = generate_hash(block)
	else:
		block["timestamp"] = get_time()
		last_block = block_chain[-1]
		block["last_hash"] = last_block["hash"]
		block["hash"] = generate_hash(block)
	block_chain.append(block)

# %%
block_chain = []
for c in chain:
    	add_block(c)

print(block_chain)

# %%
def isValidHashDifficulty(hash, difficulty):
    count = 0
    for i in hash:
        print(hash)
        print(i)
        #print(count)
        count += 1
        if(i != '0'):
            break
    return count > difficulty

def generate_hash(block):
	nonce = 0
	block["nonce"] = nonce
	hash = sha256(json.dumps(block).encode()).hexdigest()
	while(not isValidHashDifficulty(hash, 4)):
		nonce = nonce + 1
		block["nonce"] = nonce
		hash = sha256(json.dumps(block).encode()).hexdigest()
		#hash = sha256(json.dumps(block)).hexdigest()
	return hash

difficulty = 4
#hash = "abc22090".encode()
#hash = sha256("rodolfo".encode()).hexdigest()
hash = "hdf10d60331f6bac"
#print(isValidHashDifficulty(hash, difficulty))
nonce = 0
while(not isValidHashDifficulty(hash, difficulty)):
    print("hello")
    nonce = nonce + 1
    print(nonce)
    print("nonce = {}".format(nonce))
print("nonce = {}".format(nonce))
# Out:
# hdf10d60331f6bac
# h
# hello
# 1
# nonce = 1
# hdf10d60331f6bac
# h
# hello
# 2
# nonce = 2
# hdf10d60331f6bac
# h
# hello
# 3
# nonce = 3
# hdf10d60331f6bac
# h
# hello
# 4
# nonce = 4
# hdf10d60331f6bac
# h
# hello
# 5
# nonce = 5
# hdf10d60331f6bac
# h
# hello
# 6
# nonce = 6
# hdf10d60331f6bac
# h
# hello
# 7
# nonce = 7
# hdf10d60331f6bac
# h
# hello
# 8
# nonce = 8
# hdf10d60331f6bac
# h
# hello
# 9
# nonce = 9
# hdf10d60331f6bac
# h
# hello
# 10
# nonce = 10
# hdf10d60331f6bac
# h
# hello
# 11
# nonce = 11
# hdf10d60331f6bac
# h
# hello
# 12
# nonce = 12
# hdf10d60331f6bac
# h
# hello
# 13
# nonce = 13
# hdf10d60331f6bac
# h
# hello
# 14
# nonce = 14
# hdf10d60331f6bac
# h
# hello
# 15
# nonce = 15
# hdf10d60331f6bac
# h
# hello
# 16
# nonce = 16
# hdf10d60331f6bac
# h
# hello
# 17
# nonce = 17
# hdf10d60331f6bac
# h
# hello
# 18
# nonce = 18
# hdf10d60331f6bac
# h
# hello
# 19
# nonce = 19
# hdf10d60331f6bac
# h
# hello
# 20
# nonce = 20
# hdf10d60331f6bac
# h
# hello
# 21
# ...

# %%
test = 0
test = test + 1

print(test)
# Out:
# 1
